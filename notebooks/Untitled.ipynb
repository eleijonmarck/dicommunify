# %%
# -*- coding: utf-8 -*-

import os
import urllib.request
import pickle

# %matplotlib inline
import matplotlib
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt

matplotlib.pyplot.style.use = 'default'

# %%
# driving data that has been downloaded from wroscoes
file_path = '../data/processed/prep_imagedata.pkl'
with open(file_path,'rb') as f:
    X, Y = pickle.load(f)
    
print('X.shape: ', X.shape)
print('Y.shape: ', Y.shape)
imshow(X[0])
print(max(Y), min(Y), Y)
print(X[0,0,0,:])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-28-73267dc864f1> in <module>()
#       2 file_path = '../data/processed/prep_imagedata.pkl'
#       3 with open(file_path,'rb') as f:
# ----> 4     X, Y = pickle.load(f)
#       5
#       6 print('X.shape: ', X.shape)
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0x80 in position 1024: ordinal not in range(128)

# %%
from sklearn.datasets import load_boston

# %%
boston = load_boston()

# %%
print(boston.data.shape)
# Out:
# (506, 13)

# %%
plt.plot(boston.data)
# Out:
# [<matplotlib.lines.Line2D at 0x10faa0d68>,
#  <matplotlib.lines.Line2D at 0x10faa0f28>,
#  <matplotlib.lines.Line2D at 0x10faac208>,
#  <matplotlib.lines.Line2D at 0x10faac400>,
#  <matplotlib.lines.Line2D at 0x10faac5f8>,
#  <matplotlib.lines.Line2D at 0x10faac7f0>,
#  <matplotlib.lines.Line2D at 0x10faac9e8>,
#  <matplotlib.lines.Line2D at 0x10faacbe0>,
#  <matplotlib.lines.Line2D at 0x10faacdd8>,
#  <matplotlib.lines.Line2D at 0x10faacfd0>,
#  <matplotlib.lines.Line2D at 0x10faaf208>,
#  <matplotlib.lines.Line2D at 0x10faaf400>,
#  <matplotlib.lines.Line2D at 0x10faaf5f8>]

# %%
boston.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-e6f78cea6689> in <module>()
# ----> 1 boston.data.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'
